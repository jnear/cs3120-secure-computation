# %% [markdown]
# # CS3120/5120: Secure Distributed Computation
# ## In-Class Exercise, Week of 2/16/2026

# %%
import pychor
import galois
import numpy as np

p = (2**31)-1
GF = galois.GF(p)
p1 = pychor.Party('p1')
p2 = pychor.Party('p2')

@pychor.local_function
def share(x):
    s1 = GF.Random()
    s2 = GF(x) - s1
    return s1, s2

# %% [markdown]
# ## Question 1
#
# Describe how to do addition and multiplication of integers using binary MPC. Reference [Chapter 8](https://jnear.github.io/programming-mpc/chapters/chapter08.html) of the textbook.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 2
#
# How would you implement this approach?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 3
#
# What are the major considerations in deciding between binary and arithmetic MPC?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 3
#
# Consider the Boston Women's Workforce Council application described on [page 66 of the UN PET Guide](https://unstats.un.org/bigdata/task-teams/privacy/guide/2023_UN%20PET%20Guide.pdf). Also reference [the 2025 report](https://drive.google.com/file/d/1wCJT6AFkXrZ84Hne37jGhG4o00FWD3Xc/view?usp=sharing). What is the best approach for implementing this application using an MPC protocol and why?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 4
#
# Consider the Italian National Institute of Statistics application described on [page 76 of the UN PET Guide](https://unstats.un.org/bigdata/task-teams/privacy/guide/2023_UN%20PET%20Guide.pdf). What is the best approach for implementing this application using an MPC protocol and why?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 5
#
# Consider the United Nations Economic Commission For Europe lifestyle data application described on page [98 of the UN PET Guide](https://unstats.un.org/bigdata/task-teams/privacy/guide/2023_UN%20PET%20Guide.pdf). What is the best approach for implementing this application using an MPC protocol and why?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 6
#
# Describe the main idea behind Yao's garbled circuit protocol.

# %% [markdown]
# YOUR ANSWER HERE
